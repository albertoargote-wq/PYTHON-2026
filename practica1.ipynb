# %% [markdown]
# <a href="https://colab.research.google.com/github/albertoargote-wq/PYTHON-2026/blob/main/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Programa en Python Mostrar un mensaje que diga “HOLA MUNDO” en un solo renglón usando 2 print

# %%
edad = int (input ("dame tu edad:"))
nombre="carlos"
print(f"hola {nombre} tu tienes {edad} años de edad")
print(f"carlos el propximo año tendras {edad+1} años")
# Out:
# dame tu edad:44
# hola carlos tu tienes 44 años de edad
# carlos el propximo año tendras 45 años
